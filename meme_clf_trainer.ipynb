# %%
from src.modules.ai.meme_clf.meme_clf_trainer import MemeClfTrainer

# %%
MemeClfTrainer(lts=False).train_dense()
# Out:
#  val_correct  val_acc  max_val_acc trans_correct  trans_acc  max_trans_acc
#    7171/7552     0.95         0.95     7115/7552      0.942          0.942
#       name  iteration   loss  min_loss timestamp train_runtime round_runtime  \
#   meme_clf         26  0.236     0.236  07:30:23      20m, 46s      25m, 11s
#
#         uptime    total_time       eta
#   10h, 50m, 6s  10h, 50m, 6s  34m, 32s
#  17%|███████████████                                                                          | 800/4743 [06:47<33:30,  1.96it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 MemeClfTrainer(lts=False).train_dense()
#
# File C:\github\MemeHubNext\python\src\modules\ai\meme_clf\meme_clf_trainer.py:87, in MemeClfTrainer.train_dense(self)
#      85 def train_dense(self):
#      86     with self._in_eval([MemeClfLayer.FEATURES]):
# ...
