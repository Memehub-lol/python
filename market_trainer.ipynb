# %%
from src.modules.ai.stonk.market_trainer import MarketTrainer

# %%
MarketTrainer(lts=True).train()
# Out:
#   num_names_done round_runtime train_runtime market_uptime timestamp  \
# 0         25/549      11m, 45s      11m, 43s  4h, 51m, 22s  10:36:43
#
#                eta
# 0  4d, 5h, 47m, 2s
#         name val_correct  val_acc
# 0  omg karen   1594/1600    0.996
#    disappearing  stonks helth  me and the boys  finally  chef gordon ramsay
# 0         0.939         0.965            0.966    0.969               0.981
